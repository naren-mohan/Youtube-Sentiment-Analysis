# %%
!  pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# ...
#      |████████████████████████████████| 146 kB 4.0 MB/s
# ...

# %%
import os
import googleapiclient.discovery

# %%
videoID = "X34ZmkeZDos"

# %%
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyCNqLOQFSX_oD9Vq_IjYRwJVYxTUKdckFE"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId=videoID,
    order="relevance",
    maxResults=5682,
    pageToken=""
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'wRhuRdQZLjURpN7XeQob2DkS5wg', 'nextPageToken': '...', 'pageInfo': {'totalResults': 100, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'NmwfrWLjJtPdy8yenmYMczlJs0Q', 'id': 'Ugzfdefe6Mxe8lAI_P54AaABAg', 'snippet': {'videoId': 'X34ZmkeZDos', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'MH2lqTG4My1Pinf5n3KvsMns09Y', 'id': 'Ugzfdefe6Mxe8lAI_P54AaABAg', 'snippet': {'videoId': 'X34ZmkeZDos', 'textDisplay': 'Apparently, many of you thought I was sponsored by Microsoft lmao. I don&#39;t think they would approve this.', 'textOriginal': "Apparently, many of you thought I was sponsored by Microsoft lmao. I don't think they would approve this.", 'authorDisplayName': 'Joma Tech', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTFLnUPOScnD78_Lz7YCbp0PXSpPgBTI4HA0pA8=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCV0qA-eDDICsRR9rPcnG7tw', 'authorChannelId': {'va
# ...

# %%
type(response)
# Out:
# dict

# %%
import pandas as pd

# %%
response['nextPageToken']
# Out:
# '...'

# %%
response['items'][69]['snippet']['topLevelComment']['snippet']['textOriginal']
response['items'][69]['snippet']['topLevelComment']['snippet']['authorDisplayName']
response['items'][69]['snippet']['topLevelComment']['snippet']['likeCount']
response['items'][69]['snippet']['totalReplyCount']
# Out:
# 29

# %%
comment = []
author = []
like_count = []
reply_count = []

# %%
for item in response['items']:
    comment.append(item['snippet']['topLevelComment']['snippet']['textOriginal'])
    author.append(item['snippet']['topLevelComment']['snippet']['authorDisplayName'])
    like_count.append(item['snippet']['topLevelComment']['snippet']['likeCount'])
    reply_count.append(item['snippet']['totalReplyCount'])

# %%
data = {'Comments': comment,
       'Author': author,
       'LikeCount': like_count,
       'ReplyCount': reply_count}
df = pd.DataFrame(data=data)

# %%
df.head()
# Out:
#                                             Comments          Author  \
# 0  Apparently, many of you thought I was sponsore...       Joma Tech
# 1  No, PowerPoint is the best because you can mov...            CAG2
# 2  Initially, I was having difficulty to believe ...     Ishaan Jain
# 3  "This is a feature, not a bug"\n\n-- literally...  InfiniteDonuts
# 4  there is absolutely no transition between the ...     Purple Lord
#
#    LikeCount  ReplyCount
# 0       7250          53
# 1       7858          72
# 2       2581           7
# 3        549           1
# 4        254           3

# %%
nexttoken = ""
videoID = "6i-cagHpBcs"

# %%
comment = []
author = []
like_count = []
reply_count = []

nextPage = True

nexttoken = ""
videoID = "6i-cagHpBcs"

while(nextPage):
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=videoID,
        order="relevance",
        maxResults=5682,
        pageToken=nexttoken
    )
    response = request.execute()
    
    if 'nextPageToken' in response.keys():
        nexttoken = response['nextPageToken']
    else:
        nextPage = False
    
    for item in response['items']:
        comment.append(item['snippet']['topLevelComment']['snippet']['textOriginal'])
        author.append(item['snippet']['topLevelComment']['snippet']['authorDisplayName'])
        like_count.append(item['snippet']['topLevelComment']['snippet']['likeCount'])
        reply_count.append(item['snippet']['totalReplyCount'])
    
print(len(comment))
# Out:
# 276

# %%
data = {'Comments': comment,
       'Author': author,
       'LikeCount': like_count,
       'ReplyCount': reply_count}
df = pd.DataFrame(data=data)

# %%
df.shape
# Out:
# (276, 4)

# %% [markdown]
# ### Data collection over

# %% [markdown]
# ### Starting Exploratory Analysis
